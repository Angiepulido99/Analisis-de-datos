# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 

from sklearn import metrics 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

from sklearn.metrics import classification_report, confusion_matrix

# %%
Archivo = pd.read_csv("C:\Datos3\CAR DETAILS FROM CAR DEKHO.csv")

# %%
Archivo = pd.read_csv("C:\Datos3\car data.csv")

# %%
Archivo = pd.read_csv("C:\Datos3\Car details v3.csv")

# %%
Archivo = pd.read_csv("C:\Datos3\car details v4.csv")

# %%
Archivo.head(50)
# Out:
#          Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0            ritz  2014           3.35           5.59       27000    Petrol
# 1             sx4  2013           4.75           9.54       43000    Diesel
# 2            ciaz  2017           7.25           9.85        6900    Petrol
# 3         wagon r  2011           2.85           4.15        5200    Petrol
# 4           swift  2014           4.60           6.87       42450    Diesel
# 5   vitara brezza  2018           9.25           9.83        2071    Diesel
# 6            ciaz  2015           6.75           8.12       18796    Petrol
# 7         s cross  2015           6.50           8.61       33429    Diesel
# 8            ciaz  2016           8.75           8.89       20273    Diesel
# 9            ciaz  2015           7.45           8.92       42367    Diesel
# 10       alto 800  2017           2.85           3.60        2135    Petrol
# ...

# %%
Archivo.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
plt.figure(figsize=(6, 3))
sns.boxplot(x=Archivo["Selling_Price"])
plt.title("Identificación de datos faltantes y atípicos", fontsize=10)
# Out:
# Text(0.5, 1.0, 'Identificación de datos faltantes y atípicos')

# %%
plt.figure(figsize=(6, 3))
sns.boxplot(x=Archivo["Year"])
plt.title("Identificación de datos faltantes y atípicos", fontsize=10)
# Out:
# Text(0.5, 1.0, 'Identificación de datos faltantes y atípicos')

# %%
print("Cantidad de Registros con cero en Selling_Price:",Archivo["Selling_Price"].isin([0]).sum())
print("Cantidad de Registros con cero en Present_Price:",Archivo["Present_Price"].isin([0]).sum())
print("Cantidad de Registros con cero en Fuel_Type:",Archivo["Fuel_Type"].isin([0]).sum())
print("Cantidad de Registros con cero en Transmission:",Archivo["Transmission"].isin([0]).sum())
print("Cantidad de Registros con cero en Owner:",Archivo["Owner"].isin([0]).sum())
# Out:
# Cantidad de Registros con cero en Selling_Price: 0
# Cantidad de Registros con cero en Present_Price: 0
# Cantidad de Registros con cero en Fuel_Type: 0
# Cantidad de Registros con cero en Transmission: 0
# Cantidad de Registros con cero en Owner: 290

# %%
plt.figure(figsize=(6, 3))
sns.boxplot(x=Archivo["Kms_Driven"])
plt.title("Identificación de datos atípicos", fontsize=10)
# Out:
# Text(0.5, 1.0, 'Identificación de datos atípicos')

# %%
nivel_minimo=20
nivel_maximo=800
Total_Atipicos=((Archivo["Kms_Driven"]<nivel_minimo)|(Archivo["Kms_Driven"]>nivel_maximo)).sum()
print("El total de datos atipicos es {}".format(Total_Atipicos))
# Out:
# El total de datos atipicos es 299

# %%
Archivo=Archivo[(Archivo["Kms_Driven"]<nivel_maximo)&(Archivo["Kms_Driven"]>nivel_minimo)]

# %%
Total_Atipicos=((Archivo["Kms_Driven"]<nivel_minimo)|(Archivo["Kms_Driven"]>nivel_maximo)).sum()
print("El total de datos atipicos es{}".format(Total_Atipicos))
# Out:
# El total de datos atipicos es0

# %%
Archivo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, 133 to 165
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       2 non-null      object
#  1   Year           2 non-null      int64
#  2   Selling_Price  2 non-null      float64
#  3   Present_Price  2 non-null      float64
#  4   Kms_Driven     2 non-null      int64
#  5   Fuel_Type      2 non-null      object
#  6   Seller_Type    2 non-null      object
#  7   Transmission   2 non-null      object
#  8   Owner          2 non-null      int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 160.0+ bytes

# %%
Archivo["Kms_Driven"].value_counts()
# Out:
# Kms_Driven
# 500    2
# Name: count, dtype: int64

# %%
Archivo[["Kms_Driven"]].head(35)
# Out:
#      Kms_Driven
# 133         500
# 165         500
